# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
  import cv2
  import sys
  import numpy as np



  # Get user supplied values
 
  cascPath = "/content/drive/My Drive/No_headcounts/haarcascade_frontalface_default.xml"

  # Create the haar cascade
  faceCascade = cv2.CascadeClassifier(cascPath)

  # Read the image
  image = cv2.imread('/content/drive/My Drive/No_headcounts/face3.png')
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

  # Detect faces in the image
  faces = faceCascade.detectMultiScale(
      gray,
      scaleFactor=1.1,
      minNeighbors=5,
      minSize=(30, 30)
      #flags = cv2.CV_HAAR_SCALE_IMAGE
  )

  print("Found {0} faces!".format(len(faces)))

  # Draw a rectangle around the faces
  for (x, y, w, h) in faces:
      cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

  # cv2.imshow("Faces found", image)
  status = cv2.imwrite('saved.jpg', image)
  print ("Image written to file-system : ",status)
  # cv2.waitKey(0)
# Out:
# Found 6 faces!
# Image written to file-system :  True

# %%
import cv2
from google.colab.patches import cv2_imshow
face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/No_headcounts/haarcascade_frontalface_default.xml')
img = cv2.imread('/content/drive/My Drive/No_headcounts/face.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
if faces is ():
    print("No faces found")
'''We iterate through our faces array and draw a rectangle over each face in faces'''
for (x,y,w,h) in faces:
    cv2.rectangle(faces, (x,y), (x+w,y+h), (127,0,255), 2)
    cv2_imshow(faces)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
count_faces=str(len(faces))
print ("number of face(s)= " + count_faces)
# Out:
# <PIL.Image.Image image mode=L size=4x5 at 0x7FE05A3ABB70>
# <PIL.Image.Image image mode=L size=4x5 at 0x7FE05A3ABB38>
# <PIL.Image.Image image mode=L size=4x5 at 0x7FE05A3ABBA8>
# <PIL.Image.Image image mode=L size=4x5 at 0x7FE05A3ABBE0>
# <PIL.Image.Image image mode=L size=4x5 at 0x7FE05A3ABB00>
# number of face(s)= 5

# %%
import numpy as np
import cv2

face_cascade = cv2.CascadeClassifier('/content/drive/My Drive/No_headcounts/haarcascade_frontalface_default.xml')
#eye_cascade = cv2.CascadeClassifier('/content/drive/My Drive/No_headcounts/haarcascade_eye.xml')

img = cv2.imread('/content/drive/My Drive/No_headcounts/face3.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    
count_faces=str(len(faces))
print ("number of face(s)= " + count_faces)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# number of face(s)= 5
# <PIL.Image.Image image mode=RGB size=1024x427 at 0x7FE05A3AA208>
